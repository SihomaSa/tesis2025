# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Parámetros base
usuarios = [f"user_{i:03d}" for i in range(1, 301)]
plataforma = "Instagram"
sentimientos = ["Positivo", "Negativo"]
categorias = ["Académico", "Servicio", "Bienestar", "Político", "Infraestructura", "Cultura"]
emociones = {
    "Positivo": ["Alegría", "Orgullo", "Esperanza"],
    "Negativo": ["Frustración", "Tristeza", "Indignación"]
}
comentarios_positivos = [
    "Excelente atención en bienestar, gracias por el apoyo 👏",
    "Muy buena la charla sobre inteligencia artificial, sigan así 💡",
    "Felicitaciones a los docentes por su compromiso ❤️",
    "La nueva biblioteca está increíble, buen trabajo 📚",
    "Me encantó el evento cultural, San Marcos brilla ✨"
]
comentarios_negativos = [
    "Otra vez el portal colapsa cuando más lo necesitamos 😤",
    "Demasiada burocracia para un trámite simple 😡",
    "El rector no escucha a los estudiantes, decepcionante",
    "Infraestructura en mal estado, aulas sin luz ni ventilación",
    "Mucho politiqueo, deberían enfocarse en los alumnos"
]

# Generar fechas
fecha_inicio = datetime(2025, 1, 1)
fechas = [fecha_inicio + timedelta(days=i) for i in range(300)]

# Construir dataset
data = []
for i in range(300):
    usuario = usuarios[i]
    fecha = fechas[i].strftime("%Y-%m-%d")
    sentimiento = random.choice(sentimientos)
    categoria = random.choice(categorias)
    emocion = random.choice(emociones[sentimiento])
    comentario = random.choice(comentarios_positivos if sentimiento == "Positivo" else comentarios_negativos)
    
    data.append([fecha, usuario, comentario, plataforma, sentimiento, categoria, emocion])

# Crear DataFrame y guardar CSV
df = pd.DataFrame(data, columns=["fecha", "usuario", "comentario", "plataforma", "sentimiento", "categoria", "emocion"])
df.to_csv("Instagram_SanMarcos_Opiniones.csv", index=False, encoding="utf-8")

# Mostrar las primeras filas
display(df.head(10))
# Out:
#         fecha   usuario                                         comentario  \
# 0  2025-01-01  user_001  Otra vez el portal colapsa cuando más lo neces...
# 1  2025-01-02  user_002  Me encantó el evento cultural, San Marcos bril...
# 2  2025-01-03  user_003  La nueva biblioteca está increíble, buen traba...
# 3  2025-01-04  user_004  Infraestructura en mal estado, aulas sin luz n...
# 4  2025-01-05  user_005  Otra vez el portal colapsa cuando más lo neces...
# 5  2025-01-06  user_006  Otra vez el portal colapsa cuando más lo neces...
# 6  2025-01-07  user_007      Demasiada burocracia para un trámite simple 😡
# 7  2025-01-08  user_008      Demasiada burocracia para un trámite simple 😡
# 8  2025-01-09  user_009  Infraestructura en mal estado, aulas sin luz n...
# 9  2025-01-10  user_010  Excelente atención en bienestar, gracias por e...
#
#   plataforma sentimiento  categoria      emocion
# 0  Instagram    Negativo   Político  Indignación
# ...

# %%
# ▶️ Ejecuta esto en Google Colab

# !pip install openai

import openai
import pandas as pd
import random
from datetime import datetime, timedelta
import time

# Configura tu API Key
openai.api_key = "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"

# Parámetros base
usuarios = [f"user_{i:03d}" for i in range(1, 301)]
plataforma = "Instagram"
sentimientos = ["Positivo", "Negativo"]
categorias = ["Académico", "Servicio", "Bienestar", "Político", "Infraestructura", "Cultura"]
emociones = {
    "Positivo": ["Alegría", "Orgullo", "Esperanza"],
    "Negativo": ["Frustración", "Tristeza", "Indignación"]
}

# Generar fechas
fecha_inicio = datetime(2025, 1, 1)
fechas = [fecha_inicio + timedelta(days=i) for i in range(300)]

# Función para generar comentario con ChatGPT
def generar_comentario(sentimiento, categoria):
    prompt = f"""Genera un comentario breve como si fuera publicado en Instagram por un estudiante de la Universidad Nacional Mayor de San Marcos. El comentario debe tener tono {sentimiento.lower()} y tratar sobre el tema universitario de categoría "{categoria}". Usa lenguaje natural, emojis si aplica, y que parezca realista."""
    
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,
            max_tokens=100
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error al generar comentario: {e}"

# Construir dataset
data = []
for i in range(300):
    usuario = usuarios[i]
    fecha = fechas[i].strftime("%Y-%m-%d")
    sentimiento = random.choice(sentimientos)
    categoria = random.choice(categorias)
    emocion = random.choice(emociones[sentimiento])
    comentario = generar_comentario(sentimiento, categoria)
    
    data.append([fecha, usuario, comentario, plataforma, sentimiento, categoria, emocion])
    time.sleep(1.2)  # Evita sobrecargar la API

# Crear DataFrame y guardar CSV
df = pd.DataFrame(data, columns=["fecha", "usuario", "comentario", "plataforma", "sentimiento", "categoria", "emocion"])
df.to_csv("Instagram_SanMarcos_GPT.csv", index=False, encoding="utf-8")

# Mostrar algunas filas
df.head(10)
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\Usuario\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       1 # ▶️ Ejecuta esto en Google Colab
#       3 get_ipython().system('pip install openai')
# ----> 5 import openai
#       6 import pandas as pd
#       7 import random
#
# ModuleNotFoundError: No module named 'openai'
