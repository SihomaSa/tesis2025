# %%
import pandas as pd

# Cargar con manejo de errores en líneas mal formateadas
ruta_diccionario = "Datasets/DICCIONARIO_PERUANISMOS.csv"
ruta_instagram = "Datasets/Instagram_Ratings.csv"

# Intentar leer ignorando líneas problemáticas
df_diccionario = pd.read_csv(ruta_diccionario, on_bad_lines='skip', encoding='utf-8')
df_instagram = pd.read_csv(ruta_instagram, encoding='utf-8')

# Mostrar las primeras 20 filas
print("📘 DICCIONARIO_PERUANISMOS.csv")
display(df_diccionario.head(20))

print("📷 Instagram_Ratings.csv")
display(df_instagram.head(20))
# Out:
# 📘 DICCIONARIO_PERUANISMOS.csv
#                                               palabra  \
# 0   caño,Llave de metal para regular salida de líq...
# 1                                               piesa
# 2   apafa,Asociación de Padres de Familia,Neutro,S...
# 3                                             blancón
# 4                                                cala
# 5   cala,Loro pequeño de color verde con cara roja...
# 6                                             fixture
# 7                                           achorarse
# 8   calichero,Persona que trabaja en cantera de ca...
# 9   calichera,Yacimiento de residuos arenosos de c...
# 10                                           pindinga
# 11  pindingues,Dificultades, molestias, aprietos,N...
# 12                                       buscapleitos
# 13                                          emponchar
# 14  emponcharse,Embozarse o taparse con el poncho,...
# 15  chuntar,Acertar o dar en el blanco,Positivo,Ve...
# ...

# %%
import pandas as pd

# Rutas de los archivos
ruta_diccionario = "Datasets/DICCIONARIO_PERUANISMOS.csv"
ruta_instagram = "Datasets/Instagram_Ratings.csv"

# Cargar los datasets con manejo de errores
df_diccionario = pd.read_csv(ruta_diccionario, on_bad_lines='skip', encoding='utf-8')
df_instagram = pd.read_csv(ruta_instagram, encoding='utf-8')

# Mostrar info de cada DataFrame
print("📘 Información de DICCIONARIO_PERUANISMOS.csv")
df_diccionario.info()

print("\n📷 Información de Instagram_Ratings.csv")
df_instagram.info()
# Out:
# 📘 Información de DICCIONARIO_PERUANISMOS.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   palabra      162 non-null    object
#  1   significado  97 non-null     object
#  2   tipo         97 non-null     object
#  3   categoria    97 non-null     object
#  4   registro     97 non-null     object
#  5   ejemplo      0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 7.7+ KB
#
# 📷 Información de Instagram_Ratings.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  98 non-null     int64
#  1   _1       0 non-null      float64
#  2   Name     98 non-null     object
#  3   Comment  98 non-null     object
#  4   Rating   98 non-null     object
# ...

# %%
df.head(3)
